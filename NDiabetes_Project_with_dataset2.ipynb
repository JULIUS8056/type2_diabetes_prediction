# %%
import pandas as pd
diab = pd.read_excel("/content/drive/MyDrive/Julius Ogunniyi/COMBINED DATASET C_M.xlsx")

# %%
diab.head()
# Out:
#    FASTING BLOOD SUGAR (FBS)  ...  OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)
# 0                       69.0  ...                                       N
# 1                       64.0  ...                                       N
# 2                       71.0  ...                                       N
# 3                       68.0  ...                                       N
# 4                       69.0  ...                                       N
#
# [5 rows x 13 columns]

# %%
diab.isna().sum()
# Out:
# FASTING BLOOD SUGAR (FBS)                         0
# BODY MASS INDEX (BMI)                             2
# WAIST                                             0
# AGE                                               2
# GENDER                                            0
# FAMILY HISTORY OF DIABETES (FHD)                  0
# FAMILY HISTORY OF HYPERTENSION (FHH)              0
# HISTORY OF EXCESS URINE (HEU)                     0
# HISTORY OF EXCESS WATING INTAKE (HEW)             0
# PERFORM REGULAR EXERCISE (REX)                    0
# HISTORY OF EXESS FOOD (HEF)                       0
# PREVIOUS HISTORY OF DIABETES OF ANY TYPE (PHD)    0
# OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)            2
# dtype: int64

# %%
diab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 13 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   FASTING BLOOD SUGAR (FBS)                       252 non-null    float64
#  1   BODY MASS INDEX (BMI)                           250 non-null    float64
#  2   WAIST                                           252 non-null    float64
#  3   AGE                                             250 non-null    float64
#  4   GENDER                                          252 non-null    object
#  5   FAMILY HISTORY OF DIABETES (FHD)                252 non-null    object
#  6   FAMILY HISTORY OF HYPERTENSION (FHH)            252 non-null    object
#  7   HISTORY OF EXCESS URINE (HEU)                   252 non-null    object
#  8   HISTORY OF EXCESS WATING INTAKE (HEW)           252 non-null    object
# ...

# %%
diab["GENDER"].value_counts()
# Out:
# F    164
# M     88
# Name: GENDER, dtype: int64

# %%
diab["FAMILY HISTORY OF DIABETES (FHD)"].value_counts()
# Out:
# Y    165
# N     87
# Name: FAMILY HISTORY OF DIABETES (FHD), dtype: int64

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5, weights='uniform', metric='nan_euclidean')

# %%
nullnum_variables = diab[["BODY MASS INDEX (BMI)", "AGE"]]

# %%
diab[["BODY MASS INDEX (BMI)", "AGE"]] = pd.DataFrame(imputer.fit_transform(diab[["BODY MASS INDEX (BMI)", "AGE"]]),columns = nullnum_variables.columns)

# %%
diab.head()
# Out:
#    FASTING BLOOD SUGAR (FBS)  ...  OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)
# 0                       69.0  ...                                       N
# 1                       64.0  ...                                       N
# 2                       71.0  ...                                       N
# 3                       68.0  ...                                       N
# 4                       69.0  ...                                       N
#
# [5 rows x 13 columns]

# %%
diab.isna().sum()
# Out:
# FASTING BLOOD SUGAR (FBS)                         0
# BODY MASS INDEX (BMI)                             0
# WAIST                                             0
# AGE                                               0
# GENDER                                            0
# FAMILY HISTORY OF DIABETES (FHD)                  0
# FAMILY HISTORY OF HYPERTENSION (FHH)              0
# HISTORY OF EXCESS URINE (HEU)                     0
# HISTORY OF EXCESS WATING INTAKE (HEW)             0
# PERFORM REGULAR EXERCISE (REX)                    0
# HISTORY OF EXESS FOOD (HEF)                       0
# PREVIOUS HISTORY OF DIABETES OF ANY TYPE (PHD)    0
# OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)            2
# dtype: int64

# %%
diab.head()
# Out:
#    FASTING BLOOD SUGAR (FBS)  ...  OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)
# 0                       69.0  ...                                       N
# 1                       64.0  ...                                       N
# 2                       71.0  ...                                       N
# 3                       68.0  ...                                       N
# 4                       69.0  ...                                       N
#
# [5 rows x 13 columns]

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
diab["OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)"]=imp.fit_transform(diab[['OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)']])

# %%
diab.isna().sum()
# Out:
# FASTING BLOOD SUGAR (FBS)                         0
# BODY MASS INDEX (BMI)                             0
# WAIST                                             0
# AGE                                               0
# GENDER                                            0
# FAMILY HISTORY OF DIABETES (FHD)                  0
# FAMILY HISTORY OF HYPERTENSION (FHH)              0
# HISTORY OF EXCESS URINE (HEU)                     0
# HISTORY OF EXCESS WATING INTAKE (HEW)             0
# PERFORM REGULAR EXERCISE (REX)                    0
# HISTORY OF EXESS FOOD (HEF)                       0
# PREVIOUS HISTORY OF DIABETES OF ANY TYPE (PHD)    0
# OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)            0
# dtype: int64

# %%
diab.head()
# Out:
#    FASTING BLOOD SUGAR (FBS)  ...  OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)
# 0                       69.0  ...                                       N
# 1                       64.0  ...                                       N
# 2                       71.0  ...                                       N
# 3                       68.0  ...                                       N
# 4                       69.0  ...                                       N
#
# [5 rows x 13 columns]

# %%
# !pip install pyyaml==5.4.1

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.offline as py
import plotly.express as px
import plotly.io as pio
import plotly.graph_objs as go
# Out:
# /usr/local/lib/python3.7/dist-packages/distributed/config.py:20: YAMLLoadWarning:
#
# calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.

# %%
diab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 13 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   FASTING BLOOD SUGAR (FBS)                       252 non-null    float64
#  1   BODY MASS INDEX (BMI)                           252 non-null    float64
#  2   WAIST                                           252 non-null    float64
#  3   AGE                                             252 non-null    float64
#  4   GENDER                                          252 non-null    object
#  5   FAMILY HISTORY OF DIABETES (FHD)                252 non-null    object
#  6   FAMILY HISTORY OF HYPERTENSION (FHH)            252 non-null    object
#  7   HISTORY OF EXCESS URINE (HEU)                   252 non-null    object
#  8   HISTORY OF EXCESS WATING INTAKE (HEW)           252 non-null    object
# ...

# %%
diab1 = diab.copy()

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
diab1['GENDER']= label_encoder.fit_transform(diab1['GENDER'])
diab1['FAMILY HISTORY OF DIABETES (FHD)']= label_encoder.fit_transform(diab1['FAMILY HISTORY OF DIABETES (FHD)'])
diab1['FAMILY HISTORY OF HYPERTENSION (FHH)']= label_encoder.fit_transform(diab1['FAMILY HISTORY OF HYPERTENSION (FHH)'])
diab1['HISTORY OF EXCESS URINE (HEU)']= label_encoder.fit_transform(diab1['HISTORY OF EXCESS URINE (HEU)'])
diab1['HISTORY OF EXCESS WATING INTAKE (HEW)']= label_encoder.fit_transform(diab1['HISTORY OF EXCESS WATING INTAKE (HEW)'])
diab1['PERFORM REGULAR EXERCISE (REX)']= label_encoder.fit_transform(diab1['PERFORM REGULAR EXERCISE (REX)'])
diab1['HISTORY OF EXESS FOOD (HEF)']= label_encoder.fit_transform(diab1['HISTORY OF EXESS FOOD (HEF)'])
diab1['PREVIOUS HISTORY OF DIABETES OF ANY TYPE (PHD)']= label_encoder.fit_transform(diab1['PREVIOUS HISTORY OF DIABETES OF ANY TYPE (PHD)'])
diab1['OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)']= label_encoder.fit_transform(diab1['OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)'])

# %%
#Xgboost
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot
# load data
#dataset = loadtxt('pima-indians-diabetes.csv', delimiter=",")
# split data into X and y
X = diab1.iloc[:, 0:12]
y = diab1.iloc[:,12]
# fit model no training data
model = XGBClassifier()
model.fit(X, y)
# feature importance
#print(model.feature_importances_)
# plot
plot_importance(model)
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# [21:25:40] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
from numpy import sort
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=7)
# fit model on all training data
model = XGBClassifier()
model.fit(X_train, y_train)
# make predictions for test data and evaluate
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Fit model using each importance as a threshold
thresholds = sort(model.feature_importances_)
for thresh in thresholds:
	# select features using threshold
	selection = SelectFromModel(model, threshold=thresh, prefit=True)
	select_X_train = selection.transform(X_train)
	# train model
	selection_model = XGBClassifier()
	selection_model.fit(select_X_train, y_train)
	# eval model
	select_X_test = selection.transform(X_test)
	predictions = selection_model.predict(select_X_test)
	accuracy = accuracy_score(y_test, predictions)
	print("Thresh=%.3f, n=%d, Accuracy: %.2f%%" % (thresh, select_X_train.shape[1], accuracy*100.0))
# Out:
# [21:25:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Accuracy: 98.81%
# [21:25:41] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /usr/local/lib/python3.7/dist-packages/xgboost/sklearn.py:1224: UserWarning:
#
# The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
# Thresh=0.000, n=12, Accuracy: 98.81%
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,10))
cor = diab.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
diab.head()
# Out:
#    FASTING BLOOD SUGAR (FBS)  ...  OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)
# 0                       69.0  ...                                       N
# 1                       64.0  ...                                       N
# 2                       71.0  ...                                       N
# 3                       68.0  ...                                       N
# 4                       69.0  ...                                       N
#
# [5 rows x 13 columns]

# %%
data2=diab.drop(columns=["HISTORY OF EXCESS WATING INTAKE (HEW)", "PERFORM REGULAR EXERCISE (REX)", "HISTORY OF EXESS FOOD (HEF)"])

# %%
data2.head()
# Out:
#    FASTING BLOOD SUGAR (FBS)  ...  OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)
# 0                       69.0  ...                                       N
# 1                       64.0  ...                                       N
# 2                       71.0  ...                                       N
# 3                       68.0  ...                                       N
# 4                       69.0  ...                                       N
#
# [5 rows x 10 columns]

# %%
pip install pycaret[full]

# %%
import torch.nn as nn
class Net(nn.Module):
    def __init__(self, num_inputs=9, num_units_d1=200, num_units_d2=100):
        super(Net, self).__init__()
        self.dense0 = nn.Linear(num_inputs, num_units_d1)
        self.nonlin = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        self.dense1 = nn.Linear(num_units_d1, num_units_d2)
        self.output = nn.Linear(num_units_d2, 2)
        self.softmax = nn.Softmax(dim=-1)
    def forward(self, X, **kwargs):
        X = self.nonlin(self.dense0(X))
        X = self.dropout(X)
        X = self.nonlin(self.dense1(X))
        X = self.softmax(self.output(X))
        return X

# %%
pip install skorch
# Out:
# ...
#      |████████████████████████████████| 155 kB 5.9 MB/s
# ...

# %%
from skorch import NeuralNetClassifier
net = NeuralNetClassifier(
    module=Net,
    max_epochs=30,
    lr=0.1,
    batch_size=32,
    train_split=None
)

# %%
from sklearn.pipeline import Pipeline

# %%
from skorch.helper import DataFrameTransformer
nn_pipe = Pipeline(
    [
        ("transform", DataFrameTransformer()),
        ("net", net),
    ]
)

# %%
from pycaret.classification import *

# %%
data2 = data2.rename(columns={'OUTCOME(IF DIABETIC=Y, NOT DIABETIC=N)':"outcome"})

# %%
data2.head()
# Out:
#    FASTING BLOOD SUGAR (FBS)  BODY MASS INDEX (BMI)  WAIST   AGE GENDER  \
# 0                       69.0                   17.2   23.0   8.0      M
# 1                       64.0                   16.5   23.0   8.0      F
# 2                       71.0                   14.9   24.0  11.0      M
# 3                       68.0                   12.2   27.5  18.0      M
# 4                       69.0                   15.9   28.0  50.0      F
#
#   FAMILY HISTORY OF DIABETES (FHD) FAMILY HISTORY OF HYPERTENSION (FHH)  \
# 0                                N                                    N
# 1                                N                                    N
# 2                                N                                    N
# 3                                N                                    N
# 4                                N                                    N
#
#   HISTORY OF EXCESS URINE (HEU)  \
# 0                             N
# ...

# %%
dat2 = setup(data=data2, target="outcome", train_size=0.67, normalize=True,  profile=True)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-02-07 21:37:36.505426&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
skorch_model=create_model(nn_pipe)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9412  0.9861  0.8889  1.0000  0.9412  0.8828  0.8889
# 1       0.8235  1.0000  1.0000  0.7500  0.8571  0.6383  0.6847
# 2       0.8824  0.9167  1.0000  0.8182  0.9000  0.7606  0.7833
# 3       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 4       0.9412  0.9861  1.0000  0.9000  0.9474  0.8811  0.8874
# 5       0.9412  0.9857  0.9000  1.0000  0.9474  0.8811  0.8874
# 6       0.8235  0.9857  0.7000  1.0000  0.8235  0.6577  0.7000
# 7       0.8824  0.9714  1.0000  0.8333  0.9091  0.7463  0.7715
# 8       0.8125  0.8730  1.0000  0.7500  0.8571  0.6000  0.6547
# 9       0.8750  1.0000  1.0000  0.8182  0.9000  0.7377  0.7645
# Mean    0.8923  0.9705  0.9489  0.8870  0.9083  0.7786  0.8022
# SD      0.0592  0.0400  0.0929  0.1006  0.0501  0.1225  0.1048

# %%
lr = create_model('lr')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9412  1.0000  0.8889  1.0000  0.9412  0.8828  0.8889
# 1       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 2       0.9412  0.9167  1.0000  0.9000  0.9474  0.8811  0.8874
# 3       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 4       0.9412  1.0000  1.0000  0.9000  0.9474  0.8811  0.8874
# 5       0.8824  1.0000  0.8000  1.0000  0.8889  0.7671  0.7888
# 6       0.8824  0.9857  0.8000  1.0000  0.8889  0.7671  0.7888
# 7       0.9412  1.0000  0.9000  1.0000  0.9474  0.8811  0.8874
# 8       0.8125  0.8889  1.0000  0.7500  0.8571  0.6000  0.6547
# 9       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# Mean    0.9342  0.9791  0.9389  0.9550  0.9418  0.8660  0.8783
# SD      0.0578  0.0389  0.0806  0.0789  0.0480  0.1205  0.1053

# %%
pred_holdoutlr = predict_model(lr)
# Out:
#                  Model  Accuracy     AUC  Recall  Prec.      F1   Kappa     MCC
# 0  Logistic Regression    0.9167  0.9376  0.9388   0.92  0.9293  0.8279  0.8281

# %%
nb = create_model('nb')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.8824  0.9306  0.7778  1.0000  0.8750  0.7671  0.7888
# 1       0.8235  0.9722  1.0000  0.7500  0.8571  0.6383  0.6847
# 2       0.8235  0.8819  1.0000  0.7500  0.8571  0.6383  0.6847
# 3       0.8824  0.9583  0.8889  0.8889  0.8889  0.7639  0.7639
# 4       0.8824  0.9722  0.8889  0.8889  0.8889  0.7639  0.7639
# 5       0.8824  0.9714  0.9000  0.9000  0.9000  0.7571  0.7571
# 6       0.8235  0.9143  0.7000  1.0000  0.8235  0.6577  0.7000
# 7       0.8235  0.9429  0.9000  0.8182  0.8571  0.6277  0.6326
# 8       0.6875  0.5873  0.8889  0.6667  0.7619  0.3333  0.3637
# 9       0.7500  0.9365  0.8889  0.7273  0.8000  0.4754  0.4927
# Mean    0.8261  0.9068  0.8833  0.8390  0.8510  0.6423  0.6632
# SD      0.0614  0.1100  0.0852  0.1091  0.0415  0.1350  0.1292

# %%
pred_holdoutnb = predict_model(nb)
# Out:
#          Model  Accuracy    AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Naive Bayes    0.8333  0.912   0.898  0.8302  0.8627  0.6515  0.6547

# %%
svm = create_model('svm')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.8235  0.0  0.6667  1.0000  0.8000  0.6531  0.6963
# 1       0.8235  0.0  1.0000  0.7500  0.8571  0.6383  0.6847
# 2       0.8824  0.0  1.0000  0.8182  0.9000  0.7606  0.7833
# 3       1.0000  0.0  1.0000  1.0000  1.0000  1.0000  1.0000
# 4       0.9412  0.0  1.0000  0.9000  0.9474  0.8811  0.8874
# 5       1.0000  0.0  1.0000  1.0000  1.0000  1.0000  1.0000
# 6       0.9412  0.0  0.9000  1.0000  0.9474  0.8811  0.8874
# 7       0.8824  0.0  0.8000  1.0000  0.8889  0.7671  0.7888
# 8       0.8125  0.0  0.8889  0.8000  0.8421  0.6129  0.6181
# 9       0.9375  0.0  1.0000  0.9000  0.9474  0.8710  0.8783
# Mean    0.9044  0.0  0.9256  0.9168  0.9130  0.8065  0.8224
# SD      0.0668  0.0  0.1086  0.0929  0.0635  0.1353  0.1241

# %%
pred_holdoutsvm = predict_model(svm)
# Out:
#                  Model  Accuracy     AUC  ...      F1   Kappa     MCC
# 0  SVM - Linear Kernel     0.881  0.8612  ...  0.9057  0.7468  0.7626
#
# [1 rows x 8 columns]

# %%
dt = create_model('dt')
# Out:
#       Accuracy     AUC  Recall  Prec.      F1   Kappa     MCC
# 0       0.9412  0.9444  0.8889   1.00  0.9412  0.8828  0.8889
# 1       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 2       0.9412  0.9375  1.0000   0.90  0.9474  0.8811  0.8874
# 3       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 4       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 5       0.9412  0.9500  0.9000   1.00  0.9474  0.8811  0.8874
# 6       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 7       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 8       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 9       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# Mean    0.9824  0.9832  0.9789   0.99  0.9836  0.9645  0.9664
# SD      0.0270  0.0258  0.0423   0.03  0.0251  0.0542  0.0514

# %%
pred_holdoutdt = predict_model(dt)
# Out:
#                       Model  Accuracy     AUC  ...    F1   Kappa     MCC
# 0  Decision Tree Classifier    0.9524  0.9469  ...  0.96  0.9012  0.9023
#
# [1 rows x 8 columns]

# %%
xgboost = create_model('xgboost')
# Out:
#       Accuracy     AUC  Recall  Prec.      F1   Kappa     MCC
# 0       0.9412  0.9583  0.8889   1.00  0.9412  0.8828  0.8889
# 1       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 2       0.9412  0.9583  1.0000   0.90  0.9474  0.8811  0.8874
# 3       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 4       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 5       0.9412  0.9571  0.9000   1.00  0.9474  0.8811  0.8874
# 6       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 7       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 8       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 9       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# Mean    0.9824  0.9874  0.9789   0.99  0.9836  0.9645  0.9664
# SD      0.0270  0.0193  0.0423   0.03  0.0251  0.0542  0.0514

# %%
pred_holdoutxgboost = predict_model(xgboost)
# Out:
#                        Model  Accuracy     AUC  ...    F1   Kappa     MCC
# 0  Extreme Gradient Boosting    0.9524  0.9569  ...  0.96  0.9012  0.9023
#
# [1 rows x 8 columns]

# %%
catboost = create_model('catboost')
# Out:
#       Accuracy     AUC  Recall  Prec.      F1   Kappa     MCC
# 0       0.9412  1.0000  0.8889   1.00  0.9412  0.8828  0.8889
# 1       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 2       0.9412  1.0000  1.0000   0.90  0.9474  0.8811  0.8874
# 3       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 4       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 5       0.9412  0.9857  0.9000   1.00  0.9474  0.8811  0.8874
# 6       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 7       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 8       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 9       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# Mean    0.9824  0.9986  0.9789   0.99  0.9836  0.9645  0.9664
# SD      0.0270  0.0043  0.0423   0.03  0.0251  0.0542  0.0514

# %%
pred_holdoutcatboost = predict_model(catboost)
# Out:
#                  Model  Accuracy     AUC  ...      F1   Kappa     MCC
# 0  CatBoost Classifier    0.9643  0.9983  ...  0.9703  0.9256  0.9282
#
# [1 rows x 8 columns]

# %%
blender = blend_models(estimator_list = [dt, catboost, xgboost])
# Out:
#       Accuracy     AUC  Recall  Prec.      F1   Kappa     MCC
# 0       0.9412  1.0000  0.8889   1.00  0.9412  0.8828  0.8889
# 1       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 2       0.9412  1.0000  1.0000   0.90  0.9474  0.8811  0.8874
# 3       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 4       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 5       0.9412  0.9857  0.9000   1.00  0.9474  0.8811  0.8874
# 6       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 7       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 8       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 9       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# Mean    0.9824  0.9986  0.9789   0.99  0.9836  0.9645  0.9664
# SD      0.0270  0.0043  0.0423   0.03  0.0251  0.0542  0.0514

# %%
tuned_cat = tune_model(catboost)
# Out:
#       Accuracy     AUC  Recall  Prec.      F1   Kappa     MCC
# 0       0.9412  1.0000  0.8889   1.00  0.9412  0.8828  0.8889
# 1       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 2       0.9412  0.9861  1.0000   0.90  0.9474  0.8811  0.8874
# 3       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 4       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 5       0.9412  0.9857  0.9000   1.00  0.9474  0.8811  0.8874
# 6       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 7       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 8       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# 9       1.0000  1.0000  1.0000   1.00  1.0000  1.0000  1.0000
# Mean    0.9824  0.9972  0.9789   0.99  0.9836  0.9645  0.9664
# SD      0.0270  0.0056  0.0423   0.03  0.0251  0.0542  0.0514

# %%
diabetes_model = finalize_model(catboost)

# %%
save_model(diabetes_model, 'diabetes_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='outcome',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_stra...
#                  ('rem_outliers', 'passthrough'), ('cluster_all', 'passthrough'),
#                  ('dummy', Dummify(target='outcome')),
# ...

# %% [markdown]
# # Deployment

# %%
# !pip install flask_ngrok

# %%
# !pip install pyngrok
# Out:
# ...
#      |████████████████████████████████| 745 kB 5.3 MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19007 sha256=17adb634f0c461aab0a150939fe39c5e091bb6b9a441d757cd6cbe3fe6d5df89
#   Stored in directory: /root/.cache/pip/wheels/bf/e6/af/ccf6598ecefecd44104069371795cb9b3afbcd16987f6ccfb3
# Successfully built pyngrok
# ...

# %%
# !ngrok authtoken 22kQxBzJJ0L50YqAG6ubxU6WCW1_7zXr1S3Zmg2i6TsqX9LER
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
import zipfile
from zipfile import ZipFile

file_name = '/content/templates.zip'

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Extracted Successfully')
# Out:
# Extracted Successfully

# %%
data2.columns
# Out:
# Index(['FASTING BLOOD SUGAR (FBS)', 'BODY MASS INDEX (BMI)', 'WAIST', 'AGE',
#        'GENDER', 'FAMILY HISTORY OF DIABETES (FHD)',
#        'FAMILY HISTORY OF HYPERTENSION (FHH)', 'HISTORY OF EXCESS URINE (HEU)',
#        'PREVIOUS HISTORY OF DIABETES OF ANY TYPE (PHD)', 'outcome'],
#       dtype='object')

# %%
import flask
from flask import Flask, render_template, request, url_for, redirect
import pickle
import numpy as np
from flask_ngrok import run_with_ngrok
import warnings
warnings.filterwarnings('ignore')

app = Flask(__name__)
run_with_ngrok(app)

model = load_model('diabetes_model')

@app.route('/', methods=['GET'])
def home():
  return render_template('index1.html')

@app.route('/predict', methods=['GET',"POST"])
def predict():
  input_values = [x for x in request.form.values()]
  inp_features = np.array(input_values)
  col = ['AGE','FASTING BLOOD SUGAR (FBS)', 'BODY MASS INDEX (BMI)', 'WAIST', 
         'GENDER', 'FAMILY HISTORY OF DIABETES (FHD)',
       'FAMILY HISTORY OF HYPERTENSION (FHH)', 'HISTORY OF EXCESS URINE (HEU)',
       'PREVIOUS HISTORY OF DIABETES OF ANY TYPE (PHD)']
  df=pd.DataFrame([inp_features], columns=col)
  print(input_values)
  prediction = predict_model(model, data=df)
  prediction = prediction.Label[0]
  if str(prediction)=="Y":
    return render_template('index1.html', prediction_text='You are diabetic')
  else:
    return render_template('index1.html', prediction_text='Congratulations, You are not diabetic')

app.run()
# Out:
# Transformation Pipeline and Model Successfully Loaded
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://d37d-35-231-247-87.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [07/Feb/2022 23:32:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Feb/2022 23:33:00] "GET /favicon.ico HTTP/1.1" 404 -
# ['64', '307.8', '26.2', '29', 'M', 'Y', 'Y', 'Y', 'Y']
# 127.0.0.1 - - [07/Feb/2022 23:34:03] "POST /predict HTTP/1.1" 200 -
# ['40', '91.8', '26.1', '28', 'M', 'Y', 'Y', 'Y', 'Y']
# 127.0.0.1 - - [07/Feb/2022 23:36:03] "POST /predict HTTP/1.1" 200 -

# %%
pip freeze > requirements.txt
